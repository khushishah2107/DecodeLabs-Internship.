# %%
import pandas as pd 
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("raw_skills.csv")
df
# Out:
#                          Role  \
# 0              Data Scientist
# 1   Machine Learning Engineer
# 2                 AI Engineer
# 3                Data Analyst
# 4           Backend Developer
# 5          Frontend Developer
# 6        Full Stack Developer
# 7              Cloud Engineer
# 8             DevOps Engineer
# 9      Cyber Security Analyst
# 10          Software Engineer
# 11       Mobile App Developer
#
#                                                Skills
# 0   Python Machine Learning SQL Pandas NumPy Data ...
# 1    Python TensorFlow Scikit-learn Deep Learning NLP
# 2   Python TensorFlow PyTorch Deep Learning Comput...
# 3                Excel SQL Python Power BI Statistics
# 4                    Python Django Flask REST API SQL
# 5                 HTML CSS JavaScript React Bootstrap
# 6   HTML CSS JavaScript React Node.js MongoDB Express
# 7                   AWS Azure Docker Linux Kubernetes
# 8           Docker Kubernetes Jenkins Linux AWS CI/CD
# 9    Networking Linux Python Ethical Hacking Security
# 10     Java Python C++ Data Structures Algorithms OOP
# 11                      Flutter Dart Firebase Android

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df["Skills"])

# %%
user_input = input("Enter your skills (comma separated): ")
# Out:
# Enter your skills (comma separated):  html

# %%
user_vector = vectorizer.transform([user_input])

# %%
similarity_scores = cosine_similarity(user_vector, tfidf_matrix)

# %%
top_indices = similarity_scores.argsort()[0][-3:][::-1]

# %%
print("\nTop 3 Recommended Roles:\n")

for i in top_indices:
    print(df.iloc[i]["Role"])
# Out:
# Top 3 Recommended Roles:
#
# Frontend Developer
# Full Stack Developer
# Mobile App Developer
